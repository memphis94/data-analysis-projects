# %% [markdown]
# ----------
#
# ## <span style="color:green">Привет, Алексей!</span>
#
# Промотай в конец!

# %% [markdown]
# ----------
#
# ## <span style="color:red">Привет, Алексей!</span>
#
# Меня зовут **Александр Сушков** и я буду проверять твой проект. Спасибо, что сдал задание:) Ты проделал большую работу. Далее в файле ты сможешь найти мои комментарии в подобных ячейках. Пострайся учесть эти комментарии в ходе выполнения дальнейших проектов.
#
# Мне очень понравился твой проект. Видно, что ты достаточно проработал теоритическую часть, вопросы визуализации. Я вижу, что ты интересуешься материалом, которого не было, или пока не было, в теоритической части Практикума. Это очень здОрово! Тем не менее, в проекте обнаружились недочёты, которые необходимо будет исправить. Это не плохо, это - нормально.
#
# Обрати внимание, для твоего удобства, я буду выделять свои комментарии цветом, в зависимости от того, какие действия, важность и особенности тебя ждут в процессе проверки:
#
#
# -----------
# ----------
#
# 1. ## <span style="color:red">Комментарий от ревьювера (критический недочет)</span>
#
# Если ты видишь такой комментарий, значит я указываю тебе на достаточно критический недочёт, его нужно обязательно исправить. Без такого исправления я не приму твою работу:)
#
#
# -----------
# ----------
#
# 2. ## <span style="color:orange">Комментарий от ревьювера (принимаем к размышлению)</span>
#
# В таких комментариях я постараюсь подсказать тебе более элегантное или легкое решение. Поскажу некоторые хитрости и фишки. Дам рекомендации на будущее, ссылки для доп. изучения. Части проекта, помеченные такими комментариями, можно не исправлять, но рекомендую обратить на них внимание.
#
#
# -----------
# ----------
#
# 3. ## <span style="color:green">Комментарий от ревьювера (все здОрово)</span>
#
# Такими комментариями я буду помечать хорошо проделаную работу, а так же хорошо проделаную работу над ошибками:)
#
#
# -----------
# ----------
#
# #### Пожалуста, не удаляй мои комментарии. При повторной проверке, я буду ориентироваться на них.
#
# ###### Можешь под моими комментариями оставлять свои, в которых опиши свои испарвления. Это облегчит процесс проверки и мне, и тебе:)

# %% [markdown]
#  <div class="alert alert-success">
#
# **Хорошо, понял про комментарии. Буду в таком формате оставлять свои комментарии.**
# <br>
#
# </div>

# %% [markdown]
# # Определение перспективного тарифа для телеком компании.

# %% [markdown]
# ## [Заказчик]
# ### КОМПАНИЯ «МЕГАЛАЙН» — ФЕДЕРАЛЬНЫЙ ОПЕРАТОР СОТОВОЙ СВЯЗИ📞
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## Описание проекта 📃
#
# * Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
# ------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------
# ## Данные 💾
#
# #### Необходимо сделать предварительный анализ тарифов на небольшой выборке клиентов.
# #### В распоряжении данные 500 пользователей «Мегалайна»:
# * кто они
# * откуда
# * каким тарифом пользуются
# * сколько звонков и сообщений каждый отправил за 2018 год
#
# #### Данные разбиты на 5 датасетов
# * /datasets/calls.csv.
# * /datasets/internet.csv.
# * /datasets/messages.csv.
# * /datasets/tariffs.csv.
# * /datasets/users.csv.
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ## Описание тарифов 📱
# ### Тариф «Смарт»
# 1. Ежемесячная плата: 550 рублей
# 2. Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
# 3. Стоимость услуг сверх тарифного пакета:
# -------------------------------------------
# * Mинута разговора: 3 рубля
# * Cообщение: 3 рубля
# * 1 Гб интернет-трафика: 200 рублей
#
# ### Тариф «Ультра»
# 1. Ежемесячная плата: 1950 рублей
# 2. Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
# 3. Стоимость услуг сверх тарифного пакета:
# --------------------------------------------
# * Минута разговора: 1 рубль
# * Сообщение: 1 рубль
# * 1 Гб интернет-трафика: 150 рублей
# -------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------
#
# ## Цель  проекта 🎯
# * Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
#
#
# #### Важное примечание: «Мегалайн» всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута.

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## План по выполнению проекта
# ### Шаг 1. Открытие файлов с данными и изучение общей информации
# ### Шаг 2. Подготовка данных
# ### Шаг 3. Анализ данных
# ### Шаг 4. Проверка гипотез
# ### Шаг 5. Общий вывод

# %% [markdown]
# ## <span style="color:green">Комментарий от ревьювера (все здОрово)</span>
#
# Обалденное оформление)

# %% [markdown]
# <div class="alert alert-success">
#
# **Спасибо, старался. В проекте по предобработке были замечания к оформлению, постарался исправить)**
# <br>
#
# </div>

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Шаг 1. Открытие файлов с данными и изучение общей информации

# %%
#Подгружаем необходимые библиотеки
import pandas as pd
import numpy as np
import matplotlib as plt
from scipy import stats as st

# %%
#Подгружаем доступные датасеты
calls=pd.read_csv('/datasets/calls.csv') 
internet=pd.read_csv('/datasets/internet.csv') 
messages=pd.read_csv('/datasets/messages.csv')
tariffs=pd.read_csv('/datasets/tariffs.csv') 
users=pd.read_csv('/datasets/users.csv')

# %%
#Посмотрим информацию о данных
print(calls.info())
print()
print(internet.info())
print()
print(messages.info())
print()
print(tariffs.info())
print()
print(users.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null object
# duration     202607 non-null float64
# user_id      202607 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
# Unnamed: 0      149396 non-null int64
# id              149396 non-null object
# mb_used         149396 non-null float64
# session_date    149396 non-null object
# user_id         149396 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null object
# user_id         123036 non-null int64
# ...

# %%
print(calls.head())
print()
print(internet.head())
print()
print(messages.head())
print()
print(tariffs.head())
print()
print(users.head())
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000
#
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000
#
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
# ...

# %%
print(calls.describe())
print()
print(internet.describe())
print()
print(messages.describe())
print()
print(tariffs.describe())
print()
print(users.describe())
# Out:
#             duration        user_id
# count  202607.000000  202607.000000
# mean        6.755887    1253.940619
# std         5.843365     144.722751
# min         0.000000    1000.000000
# 25%         1.300000    1126.000000
# 50%         6.000000    1260.000000
# 75%        10.700000    1379.000000
# max        38.000000    1499.000000
#
#           Unnamed: 0        mb_used        user_id
# count  149396.000000  149396.000000  149396.000000
# mean    74697.500000     370.192426    1252.099842
# std     43127.054745     278.300951     144.050823
# min         0.000000       0.000000    1000.000000
# 25%     37348.750000     138.187500    1130.000000
# 50%     74697.500000     348.015000    1251.000000
# 75%    112046.250000     559.552500    1380.000000
# max    149395.000000    1724.830000    1499.000000
#
#              user_id
# count  123036.000000
# mean     1256.989410
# std       143.523967
# min      1000.000000
# 25%      1134.000000
# 50%      1271.000000
# ...

# %%
print(calls.isnull().sum())
print()
print(internet.isnull().sum())
print()
print(messages.isnull().sum())
print()
print(tariffs.isnull().sum())
print()
print(users.isnull().sum())
print()
# Out:
# id           0
# call_date    0
# duration     0
# user_id      0
# dtype: int64
#
# Unnamed: 0      0
# id              0
# mb_used         0
# session_date    0
# user_id         0
# dtype: int64
#
# id              0
# message_date    0
# user_id         0
# dtype: int64
#
# messages_included        0
# mb_per_month_included    0
# minutes_included         0
# rub_monthly_fee          0
# rub_per_gb               0
# rub_per_message          0
# rub_per_minute           0
# tariff_name              0
# dtype: int64
#
# user_id         0
# age             0
# churn_date    462
# city            0
# first_name      0
# last_name       0
# reg_date        0
# tariff          0
# dtype: int64

# %%
print('Дубликаты в данных о звонках:', calls.duplicated().sum())
print()
print('Дубликаты в данных о интернете:',internet.duplicated().sum())
print()
print('Дубликаты в данных о сообщениях:',messages.duplicated().sum())
print()
print('Дубликаты в данных о тарифах:',tariffs.duplicated().sum())
print()
print('Дубликаты в данных о пользователях:',users.duplicated().sum())
# Out:
# Дубликаты в данных о звонках: 0
#
# Дубликаты в данных о интернете: 0
#
# Дубликаты в данных о сообщениях: 0
#
# Дубликаты в данных о тарифах: 0
#
# Дубликаты в данных о пользователях: 0

# %% [markdown]
# ## <span style="color:orange">Комментарий от ревьювера (принимаем к размышлению)</span>
#
# Если ты используешь метод info(), то использование isnull() обсолютно излишне, ведь информацию о пропусках тебе уже удалось увидеть в info().

# %% [markdown]
# <div class="alert alert-success">
#
# **Принял к размышлению, точнее к исполнению. Ты прав, данный вывод тут излишний. Спасибо!**
# <br>
#
# </div>

# %% [markdown]
# ## Вывод Шаг 1
#
#
# #### Дубликатов не обнаружено
# #### Пропуски только в users.churn_date, заполнять не нужно, т.к. на момент формирования данных клиенты использовали свои тарифы
# #### Столбцы ID в calls и messages желательно переименовать, т.к. если потребуется объединять датафреймы, потеряем значения одного из них
# #### Длительность многих звонков, указана как 0.0, скорее всего это пропущенные звонки
# #### Типы данных для замены:
# * calls.call_date - object, изменить тип данных на datetime (для возможных операций с датами)
# * calls.duration - float, изменить тип данных на Int («Мегалайн» всегда округляет вверх значения минут и мегабайтов)
# * internet.mb_used - float, изменить тип данных на Int («Мегалайн» всегда округляет вверх значения минут и мегабайтов)
# * internet.session_date - object, изменить тип данных на datetime (для возможных операций с датами)
# * messages.message_date -  object, изменить тип данных на datetime (для возможных операций с датами)
# * users.churn_date - object, изменить тип данных на datetime (для возможных операций с датами)
# * users.reg_date - object, изменить тип данных на datetime (для возможных операций с датами), если потребуется т.к. есть пропуски
#
# ### Общая информация о датасетах
#
# #### Таблица users (информация о пользователях):
# * user_id — уникальный идентификатор пользователя
# * first_name — имя пользователя
# * last_name — фамилия пользователя
# * age — возраст пользователя (годы)
# * reg_date — дата подключения тарифа (день, месяц, год)
# * churn_date — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# * city — город проживания пользователя
# * tariff — название тарифного плана
#
# #### Таблица calls (информация о звонках):
# * id — уникальный номер звонка
# * call_date — дата звонка
# * duration — длительность звонка в минутах
# * user_id — идентификатор пользователя, сделавшего звонок
#
# #### Таблица messages (информация о сообщениях):
# * id — уникальный номер сообщения
# * message_date — дата сообщения
# * user_id — идентификатор пользователя, отправившего сообщение
#
# #### Таблица internet (информация об интернет-сессиях):
# * id — уникальный номер сессии
# * mb_used — объём потраченного за сессию интернет-трафика (в мегабайтах)
# * session_date — дата интернет-сессии
# * user_id — идентификатор пользователя
#
# #### Таблица tariffs (информация о тарифах):
# * tariff_name — название тарифа
# * rub_monthly_fee — ежемесячная абонентская плата в рублях
# * minutes_included — количество минут разговора в месяц, включённых в абонентскую плату
# * messages_included — количество сообщений в месяц, включённых в абонентскую плату
# * mb_per_month_included — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# * rub_per_minute — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# * rub_per_message — стоимость отправки сообщения сверх тарифного пакета
# * rub_per_gb — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# # Шаг 2. Подготовка данных

# %%
#Для начала округлим данные о мегабайтах и минутых до целых чисел
calls['duration'] = calls['duration'].apply(np.ceil)
internet['mb_used'] = internet['mb_used'].apply(np.ceil)
#Переведём тип данных на int
calls.duration=calls.duration.astype('int')
internet.mb_used=internet.mb_used.astype('int')

# %%
#Поменяем object на datetime
calls.call_date=pd.to_datetime(calls.call_date, format='%Y.%m.%d')
messages.message_date=pd.to_datetime(messages.message_date, format='%Y.%m.%d')
internet.session_date=pd.to_datetime(internet.session_date, format='%Y.%m.%d')
users.reg_date=pd.to_datetime(users.reg_date, format='%Y.%m.%d')
users.churn_date=pd.to_datetime(users.churn_date, format='%Y.%m.%d')

# %%
#Проверяем
print(calls.info())
print(messages.info())
print(users.info())
print(internet.info())
#Данные изменились, всё ок
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null datetime64[ns]
# duration     202607 non-null int64
# user_id      202607 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 6.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null datetime64[ns]
# user_id         123036 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null datetime64[ns]
# city          500 non-null object
# first_name    500 non-null object
# ...

# %%
#Поскольку есть столбец id и у данных по звонкам и по сообщениям, изменим название данных столбцов
calls.columns=['calls_id','call_date', 'duration', 'user_id']
messages.columns=['messages_id','messages_date', 'user_id' ]
#Проверим
print(calls.head())
print(messages.head())
#Всё ок
# Out:
#   calls_id  call_date  duration  user_id
# 0   1000_0 2018-07-25         0     1000
# 1   1000_1 2018-08-17         0     1000
# 2   1000_2 2018-06-11         3     1000
# 3   1000_3 2018-09-21        14     1000
# 4   1000_4 2018-12-15         6     1000
#   messages_id messages_date  user_id
# 0      1000_0    2018-06-27     1000
# 1      1000_1    2018-10-08     1000
# 2      1000_2    2018-08-04     1000
# 3      1000_3    2018-06-16     1000
# 4      1000_4    2018-12-05     1000

# %% [markdown]
# ### Посчитаем для каждого пользователя:
# * количество сделанных звонков и израсходованных минут разговора по месяцам;
# * количество отправленных сообщений по месяцам;
# * объем израсходованного интернет-трафика по месяцам;
# * помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).

# %%
#сделаем столбец с месяцем звонков
calls['month']=calls['call_date'].dt.month_name()
messages['month']=messages['messages_date'].dt.month_name()
internet['month']=internet['session_date'].dt.month_name()
print(calls.head())
print(internet.head())
print(messages.head())
# Out:
#   calls_id  call_date  duration  user_id      month
# 0   1000_0 2018-07-25         0     1000       July
# 1   1000_1 2018-08-17         0     1000     August
# 2   1000_2 2018-06-11         3     1000       June
# 3   1000_3 2018-09-21        14     1000  September
# 4   1000_4 2018-12-15         6     1000   December
#    Unnamed: 0      id  mb_used session_date  user_id      month
# 0           0  1000_0      113   2018-11-25     1000   November
# 1           1  1000_1     1053   2018-09-07     1000  September
# 2           2  1000_2     1198   2018-06-25     1000       June
# 3           3  1000_3      551   2018-08-22     1000     August
# 4           4  1000_4      303   2018-09-24     1000  September
#   messages_id messages_date  user_id     month
# 0      1000_0    2018-06-27     1000      June
# 1      1000_1    2018-10-08     1000   October
# 2      1000_2    2018-08-04     1000    August
# 3      1000_3    2018-06-16     1000      June
# ...

# %%
#Объединяем все данные в одну таблицу users и calls
pivot_users_calls = calls.pivot_table(index=['user_id', 'month'],  aggfunc={'calls_id' : 'count', 'duration' : 'sum'})
pivot_users_calls.columns = ['n_calls','duration']
#Сбрасываем индекс, чтобы не потерять значение 'month'
pivot_users_calls=pivot_users_calls.reset_index()
#display(pivot_users_calls)
 
#Объединяем все данные в одну таблицу users и messages
pivot_users_messages = messages.pivot_table(index=['user_id', 'month'], values='messages_id', aggfunc='count')
pivot_users_messages.columns = ['n_messages']
#Сбрасываем индекс, чтобы не потерять значение 'month'
pivot_users_messages=pivot_users_messages.reset_index()
#display(pivot_users_messages.sort_values(by='user_id'))
 
#Объединяем все данные в одну таблицу users и internet
pivot_users_internet = internet.pivot_table(index=['user_id', 'month'], values='mb_used', aggfunc='sum')
#Сбрасываем индекс, чтобы не потерять значение 'month'
pivot_users_internet=pivot_users_internet.reset_index()
#display(pivot_users_internet.sort_values(by='user_id'))
#print(pivot_users_internet.isna().sum())

#Объединяем все вместе
users_all = users.merge(pivot_users_calls, on='user_id', how='left')
users_all = users_all.merge(pivot_users_messages, on=['user_id', 'month'], how='left')
users_all = users_all.merge(pivot_users_internet, on=['user_id', 'month'], how='left')
 
display(users_all.head(1000))
# Out:
#      user_id  age churn_date         city first_name  last_name   reg_date  \
# 0       1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1       1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2       1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3       1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4       1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ..       ...  ...        ...          ...        ...        ...        ...
# 995     1158   45        NaT  Новокузнецк      Игорь  Андрейчук 2018-02-03
# 996     1158   45        NaT  Новокузнецк      Игорь  Андрейчук 2018-02-03
# 997     1158   45        NaT  Новокузнецк      Игорь  Андрейчук 2018-02-03
# 998     1158   45        NaT  Новокузнецк      Игорь  Андрейчук 2018-02-03
# 999     1158   45        NaT  Новокузнецк      Игорь  Андрейчук 2018-02-03
#
#     tariff     month  n_calls  duration  n_messages  mb_used
# ...

# %%
#Добавим в датафрейм с тарифами 'tariffs_name' для объединения
tariffs['tariff']=tariffs['tariff_name']
print(tariffs.head())
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name  \
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
#
#   tariff
# 0  smart
# 1  ultra

# %%
users_all_data=users_all.merge(tariffs, on='tariff', how='left')
users_all_data.head()
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#       month  n_calls  ...  n_messages  mb_used  messages_included  \
# 0    August     52.0  ...        81.0  14070.0               1000
# 1  December     46.0  ...        70.0   9827.0               1000
# 2      July     47.0  ...        75.0  14016.0               1000
# 3      June     43.0  ...        60.0  23257.0               1000
# 4       May     22.0  ...        22.0   2256.0               1000
#
#    mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# ...

# %% [markdown]
# ## <span style="color:orange">Комментарий от ревьювера (принимаем к размышлению)</span>
#
# Смотри, можно не писать print - и получается вот такая красота)

# %% [markdown]
# <div class="alert alert-success">
#
# **Исправил, теперь у меня тоже красота)**
# <br>
#
# </div>

# %%
users_all_data.head()
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#       month  n_calls  ...  n_messages  mb_used  messages_included  \
# 0    August     52.0  ...        81.0  14070.0               1000
# 1  December     46.0  ...        70.0   9827.0               1000
# 2      July     47.0  ...        75.0  14016.0               1000
# 3      June     43.0  ...        60.0  23257.0               1000
# 4       May     22.0  ...        22.0   2256.0               1000
#
#    mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# ...

# %%
#Удалим ненужный столбец tariff_name

users_all_data=users_all_data.drop(['tariff_name'], axis=1)
#del users_all_data.tariff_name
display(users_all_data.head())
# Out:
#    user_id  age churn_date       city first_name  last_name   reg_date tariff  \
# 0     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4     1000   52        NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
#
#       month  n_calls  duration  n_messages  mb_used  messages_included  \
# 0    August     52.0     408.0        81.0  14070.0               1000
# 1  December     46.0     333.0        70.0   9827.0               1000
# 2      July     47.0     340.0        75.0  14016.0               1000
# 3      June     43.0     172.0        60.0  23257.0               1000
# 4       May     22.0     159.0        22.0   2256.0               1000
#
# ...

# %%
#Получили нужный датафрейм, который показывает количество и продолжительность звонков, сообщений и израсходованный траффик по месяцам
def monthlycost(row):
       
    minutes_month_cost = 0
    messages_month_cost = 0
    mb_used_month_cost = 0
    month_cost=0
   
    if row['duration']>row['minutes_included']:
        minutes_month_cost=(row['duration']-row['minutes_included'])*row['rub_per_minute']
    if row['n_messages']>row['messages_included']:
        messages_month_cost=(row['n_messages']-row['messages_included'])*row['rub_per_message']
    if row['mb_used']>row['mb_per_month_included']:
        mb_used_month_cost=(row['mb_used']-row['mb_per_month_included'])*np.ceil(row['rub_per_gb']/1024)
    
    month_cost=minutes_month_cost+messages_month_cost+mb_used_month_cost+row['rub_monthly_fee']
    return month_cost

   

        
users_all_data['monthlycost']=users_all_data.apply(monthlycost, axis=1)

# %% [markdown]
# _____________
# ## <span style="color:red">Комментарий от ревьювера</span>
# После приведения мегабайт в гигабайты, у тебя получилось нейкое дробное число. А оператор берет деньги строго за 1 гигабайт сверх лимита:)
# Короче, проверочный показатель - конечная выручка. Еслт число дробное, значит что-то не так (так не может быть, потому что все округлено - и умножается на целые числа).
# _____________

# %% [markdown]
# <div class="alert alert-success">
#
# **Добавил np.ceil к результату перевода мегабайт в гигабайты, на выводе значения без большой дроби, .0 не мешает, но переведу в инт весь получившийся столбец**
# <br>
#
# </div>

# %%
#Переведём столбец с ежемесячными затратами в int
users_all_data['monthlycost']=users_all_data['monthlycost'].astype('int')

# %%
#Данные по ежемесячным затратам пользователей по тарифам выявлены
display(users_all_data.head(30))
users_all_data.info()
# Out:
#     user_id  age churn_date         city first_name  last_name   reg_date  \
# 0      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 5      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 6      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 7      1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 8      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 9      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 10     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 11     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# ...

# %%
#Чтобы получить более точные данные, отсечём выбросы циклом на основе диаграммы размаха по нужным столбцам
for column in ['monthlycost', 'duration', 'mb_used', 'n_messages', 'n_calls']:
    Q1 = users_all_data[column].quantile(0.25)
    Q3 = users_all_data[column].quantile(0.75)
    IQR = Q3 - Q1
    min_border = Q1-1.5*IQR
    max_border = Q3+1.5*IQR
    users_all_data.drop(users_all_data[(users_all_data[column] < min_border) | (users_all_data[column] > max_border)].index, inplace=True)

# %% [markdown]
# ## Вывод Шаг 2
#
#
# #### Минуты и мегабайты округлены по условиям тарифного плана
# #### Типы данных изменены на корректные
# #### Убраны выбросы
# #### Датафреймы объеденены, в ходе объединения выполнены следующие задачи:
# * количество сделанных звонков и израсходованных минут разговора по месяцам;
# * количество отправленных сообщений по месяцам;
# * объем израсходованного интернет-трафика по месяцам;
#
# #### Помесячная выручка с разбивкой по месяцам по каждому клиенту посчитана

# %% [markdown]
# ## <span style="color:green">Комментарий от ревьювера (все здОрово)</span>
#
# Все, кроме красного комментария, на высоте!

# %% [markdown]
# <div class="alert alert-success">
#
# **Красный комментарий исправлен, наверное). Также убраны выбросы из непрерывных количественных столбцов**
# <br>
#
# </div>

# %% [markdown]
# # Шаг 3. Анализ данных

# %% [markdown]
# Опишите поведение клиентов оператора, исходя из выборки. Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц? Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения.

# %%
#Для дальнейшего анализа нам нужны таблицы по пользователям smart и ultra

users_smart_data=users_all_data.query('tariff=="smart"')
users_ultra_data=users_all_data.query('tariff=="ultra"')

# %%
#Посмотрим среднюю выручку по пользователям тарифа "Смарт"
print('Средняя выручка по пользователям тарифа "Смарт":',users_smart_data['monthlycost'].mean())
# Out:
# Средняя выручка по пользователям тарифа "Смарт": 2760.0131004366813

# %%
#Посмотрим среднюю выручку по пользователям тарифа "Ультра"
print('Средняя выручка по пользователям тарифа "Ультра":',users_ultra_data['monthlycost'].mean())
# Out:
# Средняя выручка по пользователям тарифа "Ультра": 1993.4156378600824

# %%
users_smart_data.head()
# Out:
#     user_id  age churn_date         city first_name  last_name   reg_date  \
# 8      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 9      1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 10     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 11     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 12     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
#
#    tariff     month  n_calls  ...  n_messages  mb_used  messages_included  \
# 8   smart  December     63.0  ...         NaN  14053.0                 50
# 9   smart  November     59.0  ...         NaN  18452.0                 50
# 10  smart    August     42.0  ...        13.0  20347.0                 50
# 11  smart  December     33.0  ...        12.0  18137.0                 50
# 12  smart      July     26.0  ...        11.0  17601.0                 50
#
#     mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# ...

# %%
#Сделаем сводные таблицы для каждого тарифа по израсходованным: минутам, гигабайтам, сообщениям в месяц
#Тариф смарт
smart_minutes=users_smart_data.pivot_table(index='user_id', values='duration', aggfunc='mean') #минуты
smart_internet=users_smart_data.pivot_table(index='user_id', values='mb_used', aggfunc='mean') #трафик
smart_messages=users_smart_data.pivot_table(index='user_id', values='n_messages', aggfunc='mean') #сообщения
#Тариф ультра
ultra_minutes=users_ultra_data.pivot_table(index='user_id', values='duration', aggfunc='mean') #минуты
ultra_internet=users_ultra_data.pivot_table(index='user_id', values='mb_used', aggfunc='mean') #трафик
ultra_messages=users_ultra_data.pivot_table(index='user_id', values='n_messages', aggfunc='mean') #сообщения

# %% [markdown]
# ### Построим гистограммы плотности

# %%
import seaborn as sns
sns.distplot(smart_minutes)
smart_minutes.describe(percentiles=[.70, .80, .84, .8499, .85, .90, .95])
# Out:
#           duration
# count   348.000000
# mean    401.836907
# std     149.863899
# min       9.000000
# 50%     414.916667
# 70%     479.350000
# 80%     534.321212
# 84%     557.480000
# 84.99%  561.665673
# 85%     561.690909
# 90%     599.820000
# 95%     650.201389
# max     722.600000

# %%
sns.distplot(smart_messages)
smart_messages.describe(percentiles=[.70, .80, .84, .8499, .85, .90, .95])
# Out:
#         n_messages
# count   299.000000
# mean     36.030727
# std      24.454321
# min       1.000000
# 50%      31.000000
# 70%      46.920000
# 80%      57.200000
# 84%      62.137143
# 84.99%   64.000000
# 85%      64.000000
# 90%      72.200000
# 95%      85.100000
# max     107.000000

# %%
sns.distplot(smart_internet)
smart_internet.describe(percentiles=[.35,.70, .80, .84, .8499, .85, .90, .95])
# Out:
#              mb_used
# count     348.000000
# mean    14996.821503
# std      3800.843491
# min       371.000000
# 35%     14210.000000
# 50%     15551.166667
# 70%     16933.725000
# 80%     17980.400000
# 84%     18473.456000
# 84.99%  18625.105150
# 85%     18627.725000
# 90%     18985.127273
# 95%     20189.947917
# max     23113.666667

# %%
sns.distplot(ultra_minutes)
ultra_minutes.describe(percentiles=[.70, .80, .84, .8499, .85, .90, .95])
# Out:
#           duration
# count   136.000000
# mean    436.092700
# std     233.337649
# min      28.000000
# 50%     456.375000
# 70%     589.333333
# 80%     659.222222
# 84%     680.480000
# 84.99%  688.892000
# 85%     689.000000
# 90%     752.188889
# 95%     799.500000
# max     911.888889

# %%
sns.distplot(ultra_messages)
ultra_messages.describe(percentiles=[.70, .80, .84, .8499, .85, .90, .95])
# Out:
#         n_messages
# count   112.000000
# mean     48.735006
# std      31.016092
# min       2.000000
# 50%      45.333333
# 70%      70.360000
# 80%      78.800000
# 84%      84.240000
# 84.99%   85.000000
# 85%      85.000000
# 90%      94.575000
# 95%      97.725000
# max     120.200000

# %%
sns.distplot(ultra_internet)
ultra_internet.describe(percentiles=[.70, .80, .84, .85, .86, .87, .90, .95])
# Out:
#             mb_used
# count    134.000000
# mean   16519.849823
# std     7640.775666
# min     1445.000000
# 50%    17127.988889
# 70%    20576.033333
# 80%    23760.272727
# 84%    24990.672000
# 85%    25148.439394
# 86%    25409.706667
# 87%    25655.270000
# 90%    27132.150000
# 95%    28722.633333
# max    31359.000000

# %%
# посчитаем дисперсию, среднее и ст. отклонение по тарифу Смарт
users_smart=users_smart_data.pivot_table(index='tariff',
                                  values=['duration', 'n_messages', 'mb_used'],
                                  aggfunc=[np.mean, np.var, np.std])

# %%
users_smart.head()
# Out:
#               mean                                    var                \
#           duration       mb_used n_messages      duration       mb_used
# tariff
# smart   412.624575  15394.367833  38.077227  34307.010105  2.677582e+07
#
#                            std
#         n_messages    duration      mb_used n_messages
# tariff
# smart   669.977676  185.221516  5174.535259  25.883927

# %%
# посчитаем дисперсию, среднее и ст. отклонение по тарифу Ультра
users_ultra=users_ultra_data.pivot_table(index='tariff',
                                  values=['duration', 'n_messages', 'mb_used'],
                                  aggfunc=[np.mean, np.var, np.std])

# %%
#выведем среднее, стандартное отклонение и дисперсию по значениям тарифа Smart
users_ultra
# Out:
#               mean                                    var                \
#           duration       mb_used n_messages      duration       mb_used
# tariff
# ultra   488.834025  17068.068724  48.015707  61764.543051  6.807661e+07
#
#                             std
#          n_messages    duration      mb_used n_messages
# tariff
# ultra   1016.067935  248.524733  8250.854871  31.875821

# %%
#выведем среднее, стандартное отклонение и дисперсию по значениям тарифа Smart
users_smart
# Out:
#               mean                                    var                \
#           duration       mb_used n_messages      duration       mb_used
# tariff
# smart   412.624575  15394.367833  38.077227  34307.010105  2.677582e+07
#
#                            std
#         n_messages    duration      mb_used n_messages
# tariff
# smart   669.977676  185.221516  5174.535259  25.883927

# %% [markdown]
# ## Вывод Шаг 3
# ### Пользователи тарифа "Смарт":
# * Средняя выручка по пользователям тарифа "Смарт": 1233 рубля
# * Примерно 70% пользователей укладываются в 500 минут разговора, 30% используют минуты сверх тарифного плана
# * Примерно 70% пользователей укладываются в 50 сообщений в месяц, 30% используют сообщения сверх тарифного плана
# * Только 35% пользователей укладываются в 15 гб трафика в месяц, 30% используют трафик сверх тарифного плана
#
# ### Пользователи тарифа "Ультра":
# * Средняя выручка по пользователям тарифа "Ультра": 2060 рублей
# * Все пользователи укладываются в 3000 минут разговора, никто не использует минуты сверх тарифного плана
# * Все пользователи укладываются в 1000 минут разговора, никто не использует сообщения сверх тарифного плана
# * Примерно 86% пользователей укладываются в 30 гб трафика в месяц, 14% используют трафик сверх тарифного плана
#
# #### Пользователям тарифа "Смарт" чаще не хватает отведённых по тарифу минут, сообщений и особенно гигабайт интернет-трафика
# #### Пользователи тарифа "Ультра" не расходуют лимиты по звонкам и сообщениям, и в редких случаях идёт перерасход интернета.

# %% [markdown]
# ## <span style="color:green">Комментарий от ревьювера (все здОрово)</span>
#
# Ну просто шикарно! используешь библиотеку Seaborn. Молодец. Выше всяких похвал. Расчеты и выводы тоже на высоте)

# %% [markdown]
# <div class="alert alert-success">
#
# **Посмотрел как на консультации строились графики с её помощью, и показалось очень наглядным😀**
# <br>
#
# </div>

# %% [markdown]
# # Шаг 4. Проверьтека гипотез

# %% [markdown]
# # Гипотеза
# * **H0: Средняя выручка оператора от пользователей Смарт равна средней выручке пользователей Ультра.**
#
# * **H1: Средняя выручка оператора от пользователей Смарт отличается от выручки пользователей Ультра.**

# %% [markdown]
# ### Проверим распределение

# %%
#Проверим распределение
sns.distplot(users_smart_data['monthlycost'])

# %% [markdown]
# #### ВЫВОД О ДАННЫХ СМАРТ: Распределение, отличное от нормального со сдвигом влево.

# %%
#Построим график для визуального определения нормальности распределения
sns.distplot(users_ultra_data['monthlycost'])

# %% [markdown]
# #### ВЫВОД О ДАННЫХ УЛЬТРА: Распределение, отличное от нормального с сильным сдвигом влево.

# %% [markdown]
# * Обе выборки имеют распределение, отличное от нормального со сдвигом влево.
# * Это логично, ведь много пользователей платят абонентскую плату и не пользуются дополнительными пакетами.
# * И как мы выявили ранее, пользователи Ультра вообще редко используют дополнительные пакеты, чем и объясняется сильный сдвиг влево.

# %% [markdown]
# # Выбор критерия
# * **Тип данных:** количественный
# * **Тип распределения:** отличное от нормального
# * **Зависимость групп**: независимые (разные группы пользователей)
# * **Количество групп:** 2
#
# #### *В данном случае подойдёт критерий Манна-Уитни, поскольку он отвечает условиям нашего исследования.*

# %%
#Проведём тест Манна-Уитни для проверки гипотезы
from scipy import stats as st
smart = users_smart_data['monthlycost']
ultra = users_ultra_data['monthlycost']

alpha = .05
results = st.mannwhitneyu(smart, ultra, alternative='two-sided')

print('p-значение: {:.10f}'.format(results.pvalue))

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.0000419785
# Отвергаем нулевую гипотезу

# %% [markdown]
# ### Подтвердилась гипотеза H1: Средняя выручка оператора от пользователей Смарт отличается от выручки пользователей Ультра.

# %% [markdown]
# ## <span style="color:red">Комментарий от ревьювера (критический недочет)</span>
#
# Давай тут немножечко поправим)
#
# 1. Нужно понимать, что формулировка не терпит понятий "следующая, первая, и т.д." Есть нулевая и альтернативная. Лучше всего, если это будет выглядеть так.
#
#     H0: Средняя выручка оператора от пользователей из Москвы равна средней выручке пользователей из регионов.
#
#     H1: Средняя выручка оператора от пользователей из Москвы отличается от выручки пользователей из регионов.
#
# 2. Если мы используем т-тест, нужно это обосновать, типа "В данном тесте мы используем статистический критерий Стьюдента, потому что то-то и то-то, данные распределены так-то, и представляют из себя бла-бла-бла"
#
# Посмотри тут: https://www.youtube.com/watch?v=ZaZYy0YUdY8&feature=emb_logo
#
# А чтоб окончательно взорвать тебе мозг, прочитай тут: https://drive.google.com/file/d/1SqcimkyF4iGjgT8Yhlmx-tOXV-ejmFev/view?usp=sharing

# %% [markdown]
# <div class="alert alert-success">
#
# **Немного подправил, надеюсь корректно**
#
# **Видео супер, помогло мне быстро определить необходимый критерий для исследования**
#
# **Взрыв мозга с файла на гугл диске не случился, за исключением применения в Python, описываемые понятия были в курсе по статистике на степике, только там ещё с обилием математических формул🤯**
#
# Спасибо за материалы, пригодились!
#
# <br>
#
# </div>

# %% [markdown]
# # Гипотеза
# * **H0: Средняя выручка оператора от пользователей из Москвы равна средней выручке пользователей из регионов.**
#
# * **H1: Средняя выручка оператора от пользователей из Москвы отличается от выручки пользователей из регионов.**

# %%
#Сделаем срезы по данным их Москвы и данным из регионов
moscow=users_all_data.query('city=="Москва"')
russia=users_all_data.query('city!="Москва"')

# %%
moscow['monthlycost'].describe()
# Out:
# count     537.000000
# mean     2471.897579
# std      2147.879720
# min       550.000000
# 25%       721.000000
# 50%      1950.000000
# 75%      3109.000000
# max      9923.000000
# Name: monthlycost, dtype: float64

# %%
russia['monthlycost'].describe()
# Out:
# count    2253.000000
# mean     2580.638260
# std      2315.929537
# min       550.000000
# 25%       640.000000
# 50%      1950.000000
# 75%      3536.000000
# max      9927.000000
# Name: monthlycost, dtype: float64

# %% [markdown]
# ### Проверим распределение

# %%
sns.distplot(moscow['monthlycost'])

# %% [markdown]
# #### ВЫВОД О ДАННЫХ МОСКВА: Распределение, отличное от нормального со сдвигом влево.

# %%
sns.distplot(russia['monthlycost'])

# %% [markdown]
# #### ВЫВОД О ДАННЫХ РЕГИОНЫ: Распределение, отличное от нормального со сдвигом влево.

# %% [markdown]
# #### ОБЩИЙ ВЫВОД: Обе выборки имеют распределение, отличное от нормального со сдвигом влево.

# %% [markdown]
# # Выбор критерия
# * **Тип данных:** количественный
# * **Тип распределения:** отличное от нормального
# * **Зависимость групп**: независимые (разные группы пользователей)
# * **Количество групп:** 2
#
# #### *В данном случае также, как и в первом подойдёт критерий Манна-Уитни, поскольку он отвечает условиям нашего исследования.*

# %%
#Проведём тест Манна-Уитни для проверки гипотезы

moscow_income=moscow['monthlycost']
russia_income=['monthlycost']

alpha = .05
results = st.mannwhitneyu(moscow_income, russia_income, alternative='two-sided')

print('p-значение: {:.10f}'.format(results.pvalue))

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.0785502320
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ### Подтвердилась гипотеза H0: Средняя выручка оператора от пользователей из Москвы равна средней выручке пользователей из регионов.

# %% [markdown]
# # Шаг 5. Общий вывод

# %% [markdown]
# ### В ходе нашего исследования мы выяснили следующее:
#
# * Тариф "Ультра" в среднем приносит больше денег, чем тариф "Смарт" (2060 рублей против 1233 рубля)
# * Пользователи тарифа "Ультра" в основном не расходуют включенные в тариф минуты, сообщения и трафик (за редким исключением)
# * 25% пользователей тарифа "Смарт" платят больше, чем базовая стоимость тарифа "Ультра".
#
# #### Зависимость средней выручки от типа тарифа, Смарт или Ультра
# ##### Подтвердилась гипотеза H1: Средняя выручка оператора от пользователей Смарт отличается от выручки пользователей Ультра.
# #### Зависимость средней выручки от географии пользователей, Москва или Регионы
# ##### Подтвердилась гипотеза H0: Средняя выручка оператора от пользователей из Москвы равна средней выручке пользователей из регионов.
#
# ## На основе приведённых данных, можно сделать вывод, что тариф "Ультра" лучше для компании, т.к. выручка по тарифу выше, а включенные минуты, сообщения и трафик не перерасходуются. И в итоге пользователь платит за то, что ему не нужно. Можно сказать за "воздух" и автоматически всегда переплачивает.
#
# Оффтоп[Если конечно подходить с очень клиентоориентированной позицией, то необходим промежуточный тариф, между "Смарт" и "Ультра", чтобы удовлетворить максимальное число пользователей. И 15гб интернета в наше время?? Очень скудно.]
#
# ##### От ревьювера, как от человека - это вы еще в Беларуси не жили)

# %% [markdown]
# ## <span style="color:red">Комментарий от ревьювера </span>
# Что в целом? У тебя очень достойная работат. Несколько доработок, и все будет замечательно.
#
# Вот мои общие рекомендации:
#
# 1. Про комментарии. Молодец что комментируешь код. Дам жизненый совет. Я, например, комментирую почти каждую строчку кода.  У нас как-то накрылся сервер, да так накрылся, что написанные программы восстанавливали только в виде текстовых файлов. Вот мне все завидовали, что у меня каждая строчка подписана:)
#
# 2. Посмотри пункт про гигабайты.
#
# 3. Доработай статистику)
#
# 4. Ты никак не работаешь с выбросами. Подумай над этим пунктом. Не воспринимай это как вызов. Если ты считаешь, что с выбросами работать не нужно, обоснуй - почему. Ты аналитик, тебе решать)
#
# Видишь, совсем немного)
#
# Видно, что ты растешь как аналитик, дополнительно интересуешься крутыми фишками. Это здорово! Несколько шажков, и ты доведешь свой проект почти до идеала:) Буду ждать твоих исправлений:)
#
# <img src="https://i.pinimg.com/564x/5d/e8/4c/5de84c68671d469df72441ea520ef183.jpg" width="240">

# %% [markdown]
# <div class="alert alert-success">
#
# **Александр, спасибо большое за качественное и подробное ревью!**
#
# **Постарался исправить замечания, отображённые в рекомендациях:**
# 1. Комментарии наше всё)
# 2. Пункт про гигабайты постарался исправить, округлил до целых значений
# 3. Статистику вроде доработал, по анализу данных подошёл критерий Манна-Уитни, т.к. распределения отличные от нормального
# 4. Выбросы попробовал сократить в последней строчке Шага 2
#
# P.S.: Мне не хватило знаний, данных в тренажёре. Пришлось пока ждал ревью пройти курс "Основы статистики" на stepik (Даже сертификат получил). И также заказал себе книгу "Статистика и котики", понимаю, что книжка поверхностная, но мне нужно чтобы у меня очень хорошо отложились основы и понятия статистики😄
# <br>
#
# </div>

# %% [markdown]
# ## <span style="color:green">Комментарий от ревьювера (все здОрово)</span>
#
# Твое стремление очень похвально) Ты все поправил, и это здорово. А про нехватку знаний я напишу коллегам обязательно)  Короче, молодец! Я желаю тебе успехов в учебе, а с твоим подходом, уситчивостью и старанием, я думаю, успех не заставит долго ждать. Удачи!
